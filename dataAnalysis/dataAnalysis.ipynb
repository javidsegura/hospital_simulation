# %%
import numpy as np
import pandas as pd

# %%
PATH = "../other/results.csv"
df = pd.read_csv(PATH)

# %%
# Create a nested dictionary to group metrics by all underscore levels
grouped_metrics = {}

for col in df.columns:
    parts = col.split('_')
    
    # Navigate/create nested dictionary structure
    current_dict = grouped_metrics
    for level in parts[:-1]:  # All parts except the last one are levels
        if level not in current_dict:
            current_dict[level] = {}
        current_dict = current_dict[level]
    
    # Store the final value
    final_level = parts[-1]
    if isinstance(current_dict, dict):
        current_dict[final_level] = df[col].mean()

# Helper function to print nested dictionary with proper indentation
def print_nested_dict(d, indent=0):
    for key, value in d.items():
        print("    " * indent + f"{key}:")
        if isinstance(value, dict):
            print_nested_dict(value, indent + 1)
        else:
            print("    " * (indent + 1) + f"- {value}")

# Print grouped metrics in desired format
print_nested_dict(grouped_metrics)
# Out:
# general:
#     totalTime:
#         - 20138.834955273676
#     totalPatients:
#         - 9279.4
# proportion:
#     CriticalPatients:
#         - 0.05995960249636899
#     UrgentPatients:
#         - 0.1640079303810436
#     ModeratePatients:
#         - 0.4706352407466695
#     LowPatients:
#         - 0.19393619716291244
#     NonUrgentPatients:
#         - 0.1119781762854265
#     totalPatientsDeclinedAccess:
#         - 0.0
# arrival:
#     waitingTime:
#         average:
#             - 2.0153599921699135
#         total:
#             - 18701.25512910373
# reception:
#     serviceTime:
#         duration:
#             average:
#                 - 3.0089300792130484
#             total:
#                 - 27921.04309513246
#     waitingInQueue:
#         duration:
#             average:
#                 - 3.796921768493875
#             total:
#                 - 35232.821896956346
# nurse:
#     proportion:
#         moderatePatients:
#             - 0.7165736297571649
#         lowPatients:
#             - 0.28342637024283496
#     serviceTime:
#         duration:
#             moderate:
#                 average:
#                     - 3.6271372681670484
#                 total:
#                     - 16890.633468180546
#             low:
#                 average:
#                     - 4.427235623285837
#                 total:
#                     - 8155.021773293677
#     waitingInQueue:
#         duration:
#             moderate:
#                 average:
#                     - 0.06560302110939728
#                 total:
#                     - 305.23425440752527
#             low:
#                 average:
#                     - 0.10142958763765256
#                 total:
#                     - 186.6893807431628
#     revaluations:
#         moderate:
#             toCritical:
#                 - 0.018656711688654088
#             toUrgent:
#                 - 0.02409380325688914
#             toModerate:
#                 - 0.9207093487966624
#             toLow:
#                 - 0.031284486264851086
#             toNon-urgent:
#                 - 0.005363391442259941
#         low:
#             toCritical:
#                 - 0.00016197435376521
#             toUrgent:
#                 - 0.010097611687005771
#             toModerate:
#                 - 0.04317820359353325
#             toLow:
#                 - 0.8979204699355761
#             toNon-urgent:
#                 - 0.04885998153850605
# doctor:
#     proportion:
#         totalPatients:
#             - 8245.1
#         criticalPatients:
#             - 0.06747647516723956
#         urgentPatients:
#             - 0.1845898500624077
#         moderatePatients:
#             - 0.5296811960405036
#         lowPatients:
#             - 0.21825247872984913
#     serviceTime:
#         duration:
#             critical:
#                 average:
#                     - 5.09062420683714
#                 total:
#                     - 2831.449667805796
#             urgent:
#                 average:
#                     - 6.937131174704318
#                 total:
#                     - 10560.313758214634
#             moderate:
#                 average:
#                     - 10.093272199122513
#                 total:
#                     - 44079.42738440454
#             low:
#                 average:
#                     - 9.998680151035263
#                 total:
#                     - 17996.689833184188
#     waitingInQueue:
#         duration:
#             critical:
#                 average:
#                     - 0.4551657090839162
#                 total:
#                     - 253.41783629000048
#             urgent:
#                 average:
#                     - 0.5800491314903203
#                 total:
#                     - 882.6718179251004
#             moderate:
#                 average:
#                     - 1.0999841480355004
#                 total:
#                     - 4802.979736198375
#             low:
#                 average:
#                     - 2.902485652651619
#                 total:
#                     - 5226.4892769853
#     assesment:
#         criticalEnterHospitalRatio:
#             - 0.9907658723261342
#         urgentEnterHospitalRatio:
#             - 0.9507480957736926
#         moderateEnterHospitalRatio:
#             - 0.45255576418009574
#         lowEnterHospitalRatio:
#             - 0.10255852600472151
# financials:
#     entryRate:
#         - 0.4823882497653066
#     revenue:
#         total:
#             - 3490895.0
#         perPatientAverage:
#             - 376.19699114519216
#     expenses:
#         total:
#             - 244041.55097034207
#         perPatientAverage:
#             - 26.29938696124206
#     profit:
#         total:
#             - 3246853.449029658
#         perPatientAverage:
#             - 349.8976041839501
