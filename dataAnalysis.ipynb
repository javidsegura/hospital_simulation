# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("results.csv")

# %%
df["critical"]
# Out:
#    general_totalTime  general_totalPatients  proportion_CriticalPatients  \
# 0       19969.037828                   9245                     0.062845
# 1       19939.875539                   9270                     0.059763
# 2       20033.311730                   9287                     0.063960
# 3       20199.200561                   9299                     0.055812
# 4       20320.513986                   9306                     0.059639
# 5       20034.297534                   9220                     0.061931
# 6       20160.832856                   9306                     0.061896
# 7       20067.532718                   9263                     0.060995
# 8       19986.199954                   9261                     0.057985
# 9       20241.193615                   9290                     0.060388
#
#    proportion_UrgentPatients  proportion_ModeratePatients  \
# 0                   0.168199                     0.465657
# 1                   0.167098                     0.475836
# 2                   0.166792                     0.467751
# 3                   0.163351                     0.475643
# 4                   0.166882                     0.465721
# 5                   0.167679                     0.465618
# 6                   0.170858                     0.472061
# 7                   0.169276                     0.467235
# 8                   0.165425                     0.469604
# 9                   0.169968                     0.471798
#
#    proportion_LowPatients  proportion_NonUrgentPatients  \
# 0                0.216874                      0.110871
# 1                0.204207                      0.116397
# 2                0.204695                      0.112523
# 3                0.208087                      0.111625
# 4                0.208683                      0.112830
# 5                0.217354                      0.108568
# 6                0.199334                      0.110037
# 7                0.208896                      0.109792
# 8                0.209913                      0.114566
# 9                0.204952                      0.109257
#
#    proportion_totalPatientsDeclinedAccess  arrival_waitingTime_average  \
# 0                                       0                     2.004393
# 1                                       0                     1.995687
# 2                                       0                     2.002090
# 3                                       0                     2.017913
# 4                                       0                     2.029117
# 5                                       0                     2.016737
# 6                                       0                     2.011844
# 7                                       0                     2.011100
# 8                                       0                     2.002643
# 9                                       0                     2.023873
#
#    arrival_waitingTime_total  ...  doctor_assesment_urgentEnterHospitalRatio  \
# 0               18530.612503  ...                                   0.892298
# 1               18500.013920  ...                                   0.879259
# 2               18593.406325  ...                                   0.868687
# 3               18764.568814  ...                                   0.890943
# 4               18882.964914  ...                                   0.884892
# 5               18594.319358  ...                                   0.901589
# 6               18722.220613  ...                                   0.895698
# 7               18628.819575  ...                                   0.879250
# 8               18546.474348  ...                                   0.874320
# 9               18801.776139  ...                                   0.887441
#
#    doctor_assesment_moderateEnterHospitalRatio  \
# 0                                     0.414692
# 1                                     0.430160
# 2                                     0.418350
# 3                                     0.417564
# 4                                     0.418225
# 5                                     0.418115
# 6                                     0.413113
# 7                                     0.424752
# 8                                     0.414472
# 9                                     0.420906
#
#    doctor_assesment_lowEnterHospitalRatio  financials_entryRate  \
# 0                                0.098108              0.480692
# 1                                0.101266              0.485437
# 2                                0.111111              0.485087
# 3                                0.085523              0.474567
# 4                                0.108795              0.481840
# 5                                0.102743              0.487961
# 6                                0.092168              0.483881
# 7                                0.104103              0.490554
# 8                                0.092402              0.473491
# 9                                0.093181              0.482885
#
#    financials_revenue_total  financials_revenue_perPatientAverage  \
# 0                   3507150                            379.356409
# 1                   3497500                            377.292341
# 2                   3523900                            379.444385
# 3                   3450800                            371.093666
# 4                   3488850                            374.903288
# 5                   3513000                            381.019523
# 6                   3528450                            379.158607
# 7                   3535100                            381.636619
# 8                   3448400                            372.357197
# 9                   3515450                            378.412271
#
#    financials_expenses_total  financials_expenses_perPatientAverage  \
# 0              230904.097116                              24.976106
# 1              229051.645757                              24.708915
# 2              226849.959469                              24.426613
# 3              229497.822220                              24.679839
# 4              226845.377795                              24.376249
# 5              233810.576897                              25.359065
# 6              227814.874010                              24.480429
# 7              230100.694293                              24.840839
# 8              229598.525277                              24.791980
# 9              232027.498403                              24.976049
#
#    financials_profit_total  financials_profit_perPatientAverage
# 0             3.276246e+06                           354.380303
# 1             3.268448e+06                           352.583425
# 2             3.297050e+06                           355.017771
# 3             3.221302e+06                           346.413827
# 4             3.262005e+06                           350.527039
# 5             3.279189e+06                           355.660458
# 6             3.300635e+06                           354.678178
# 7             3.304999e+06                           356.795780
# 8             3.218801e+06                           347.565217
# 9             3.283423e+06                           353.436222
#
# [10 rows x 66 columns]

# %%
df["doctor_assesment_criticalEnterHospitalRatio"].value_counts()
# Out:
# doctor_assesment_criticalEnterHospitalRatio
# 0.923688    1
# 0.929530    1
# 0.942857    1
# 0.913732    1
# 0.942275    1
# 0.931485    1
# 0.936585    1
# 0.929276    1
# 0.924269    1
# 0.916667    1
# Name: count, dtype: int64

# %%
# Create a nested dictionary to group metrics by all underscore levels
grouped_metrics = {}

for col in df.columns:
    parts = col.split('_')
    
    # Navigate/create nested dictionary structure
    current_dict = grouped_metrics
    for level in parts[:-1]:  # All parts except the last one are levels
        if level not in current_dict:
            current_dict[level] = {}
        current_dict = current_dict[level]
    
    # Store the final value
    final_level = parts[-1]
    if isinstance(current_dict, dict):
        current_dict[final_level] = df[col].mean()

# Helper function to print nested dictionary with proper indentation
def print_nested_dict(d, indent=0):
    for key, value in d.items():
        print("    " * indent + f"{key}:")
        if isinstance(value, dict):
            print_nested_dict(value, indent + 1)
        else:
            print("    " * (indent + 1) + f"- {value}")

# Print grouped metrics in desired format
print_nested_dict(grouped_metrics)
# Out:
# general:
#     totalTime:
#         - 20095.199632052703
#     totalPatients:
#         - 9274.7
# proportion:
#     CriticalPatients:
#         - 0.060521333361900374
#     UrgentPatients:
#         - 0.16755266526991988
#     ModeratePatients:
#         - 0.469692318417749
#     LowPatients:
#         - 0.20829923474785045
#     NonUrgentPatients:
#         - 0.11164661766199697
#     totalPatientsDeclinedAccess:
#         - 0.0
# arrival:
#     waitingTime:
#         average:
#             - 2.0115395646592633
#         total:
#             - 18656.51765077636
# reception:
#     serviceTime:
#         duration:
#             average:
#                 - 3.0212984583977938
#             total:
#                 - 28022.073832199465
#     waitingInQueue:
#         duration:
#             average:
#                 - 3.6892933843838973
#             total:
#                 - 34217.114354979065
# nurse:
#     proportion:
#         moderatePatients:
#             - 0.714728712515971
#         lowPatients:
#             - 0.28527128748402886
#     serviceTime:
#         duration:
#             moderate:
#                 average:
#                     - 3.6228092074046216
#                 total:
#                     - 16771.202192518955
#             low:
#                 average:
#                     - 4.509253618500189
#                 total:
#                     - 8333.336467745368
#     waitingInQueue:
#         duration:
#             moderate:
#                 average:
#                     - 0.0730079508499833
#                 total:
#                     - 338.10833915949604
#             low:
#                 average:
#                     - 0.1036963415766454
#                 total:
#                     - 192.00550986931233
#     revaluations:
#         moderate:
#             toCritical:
#                 - 0.02048465241895115
#             toUrgent:
#                 - 0.02583317510307658
#             toModerate:
#                 - 0.9197742904237834
#             toLow:
#                 - 0.02887438308091229
#             toNon-urgent:
#                 - 0.00516303028384632
#         low:
#             toCritical:
#                 - 5.302226935312e-05
#             toUrgent:
#                 - 0.010788218248292663
#             toModerate:
#                 - 0.03884465076465837
#             toLow:
#                 - 0.9015882877195249
#             toNon-urgent:
#                 - 0.04905275726015358
# doctor:
#     proportion:
#         totalPatients:
#             - 8883.2
#         criticalPatients:
#             - 0.06800206518571476
#         urgentPatients:
#             - 0.1878937095125819
#         moderatePatients:
#             - 0.5254811304181523
#         lowPatients:
#             - 0.2186230948835509
#     serviceTime:
#         duration:
#             critical:
#                 average:
#                     - 4.609459901256744
#                 total:
#                     - 2783.1038536845776
#             urgent:
#                 average:
#                     - 6.517949035342362
#                 total:
#                     - 10878.572919392187
#             moderate:
#                 average:
#                     - 9.399598234948757
#                 total:
#                     - 43877.69468154166
#             low:
#                 average:
#                     - 14.823356416849029
#                 total:
#                     - 28788.839837824555
#     waitingInQueue:
#         duration:
#             critical:
#                 average:
#                     - 3.069598347280615
#                 total:
#                     - 1853.6482221838025
#             urgent:
#                 average:
#                     - 4.120721499436097
#                 total:
#                     - 6877.199785241627
#             moderate:
#                 average:
#                     - 397.5106289564215
#                 total:
#                     - 1857335.8303553597
#             low:
#                 average:
#                     - 15125.485293072556
#                 total:
#                     - 29380988.745314598
#     assesment:
#         criticalEnterHospitalRatio:
#             - 0.929036452862561
#         urgentEnterHospitalRatio:
#             - 0.8854377145899128
#         moderateEnterHospitalRatio:
#             - 0.41903501895719825
#         lowEnterHospitalRatio:
#             - 0.09893997085697456
# financials:
#     entryRate:
#         - 0.4826394614337307
#     revenue:
#         total:
#             - 3500860.0
#         perPatientAverage:
#             - 377.4674305603734
#     expenses:
#         total:
#             - 229650.10712374427
#         perPatientAverage:
#             - 24.76160853972525
#     profit:
#         total:
#             - 3271209.8928762553
#         perPatientAverage:
#             - 352.70582202064816
