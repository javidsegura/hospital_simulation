# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("results.csv")

# %%
df
# Out:
#    general_totalTime  general_totalPatients  proportion_CriticalPatients  \
# 0         206.191037                    100                         0.06
#
#    proportion_UrgentPatients  proportion_ModeratePatients  \
# 0                       0.19                         0.48
#
#    proportion_LowPatients  proportion_NonUrgentPatients  \
# 0                    0.17                           0.1
#
#    proportion_totalPatientsDeclinedAccess  arrival_waitingTime_average  \
# 0                                       0                      2.06191
#
#    arrival_waitingTime_total  ...  \
# 0                 206.191037  ...
#
#    doctor_assesment_criticalEnterHospitalRatio  \
# 0                                          1.0
#
#    doctor_assesment_urgentEnterHospitalRatio  \
# 0                                        1.0
#
#    doctor_assesment_moderateEnterHospitalRatio  \
# 0                                     0.458333
#
#    doctor_assesment_lowEnterHospitalRatio  totalFinancials  \
# 0                                0.058824            36900
#
#    averageRevenuePerPatient  hospitalEntryRate  totalExpenses   totalProfit  \
# 0                     369.0               0.48    7279.860878  29620.139122
#
#    averageProfitPerPatient
# 0               296.201391
#
# [1 rows x 65 columns]

# %%
df["general_totalTime"]
# Out:
# 0    206.191037
# Name: general_totalTime, dtype: float64

# %%
# Create a nested dictionary to group metrics by all underscore levels
grouped_metrics = {}

for col in df.columns:
    parts = col.split('_')
    
    # Navigate/create nested dictionary structure
    current_dict = grouped_metrics
    for level in parts[:-1]:  # All parts except the last one are levels
        if level not in current_dict:
            current_dict[level] = {}
        current_dict = current_dict[level]
    
    # Store the final value
    final_level = parts[-1]
    if isinstance(current_dict, dict):
        current_dict[final_level] = df[col].mean()

# Helper function to print nested dictionary with proper indentation
def print_nested_dict(d, indent=0):
    for key, value in d.items():
        print("    " * indent + f"{key}:")
        if isinstance(value, dict):
            print_nested_dict(value, indent + 1)
        else:
            print("    " * (indent + 1) + f"- {value}")

# Print grouped metrics in desired format
print_nested_dict(grouped_metrics)
# Out:
# general:
#     totalTime:
#         - 206.19103747331044
#     totalPatients:
#         - 100.0
# proportion:
#     CriticalPatients:
#         - 0.06
#     UrgentPatients:
#         - 0.19
#     ModeratePatients:
#         - 0.48
#     LowPatients:
#         - 0.17
#     NonUrgentPatients:
#         - 0.1
#     totalPatientsDeclinedAccess:
#         - 0.0
# arrival:
#     waitingTime:
#         average:
#             - 2.061910374733104
#         total:
#             - 206.19103747331044
# reception:
#     serviceTime:
#         duration:
#             average:
#                 - 11.043460819766018
#             total:
#                 - 1104.346081976602
#     waitingInQueue:
#         duration:
#             average:
#                 - 181.4272817158187
#             total:
#                 - 18142.72817158187
# nurse:
#     proportion:
#         moderatePatients:
#             - 0.7536231884057971
#         lowPatients:
#             - 0.2463768115942029
#     serviceTime:
#         duration:
#             moderate:
#                 average:
#                     - 2.7614103101187606
#                 total:
#                     - 143.59333612617556
#             low:
#                 average:
#                     - 4.345864935967831
#                 total:
#                     - 73.87970391145312
#     waitingInQueue:
#         duration:
#             moderate:
#                 average:
#                     - 0.0061269260685234
#                 total:
#                     - 0.3186001555632174
#             low:
#                 average:
#                     - 0.0
#                 total:
#                     - 0.0
#     revaluations:
#         moderate:
#             toCritical:
#                 - 0.0384615384615384
#             toUrgent:
#                 - 0.0192307692307692
#             toModerate:
#                 - 0.9230769230769232
#             toLow:
#                 - 0.0192307692307692
#             toNon-urgent:
#                 - 0.0
#         low:
#             toCritical:
#                 - 0.0
#             toUrgent:
#                 - 0.0
#             toModerate:
#                 - 0.0
#             toLow:
#                 - 0.9411764705882352
#             toNon-urgent:
#                 - 0.0588235294117647
# doctor:
#     proportion:
#         totalPatients:
#             - 90.0
#         criticalPatients:
#             - 0.0666666666666666
#         urgentPatients:
#             - 0.2111111111111111
#         moderatePatients:
#             - 0.5333333333333333
#         lowPatients:
#             - 0.1888888888888888
#     serviceTime:
#         duration:
#             critical:
#                 average:
#                     - 17.430718820090686
#                 total:
#                     - 104.58431292054412
#             urgent:
#                 average:
#                     - 23.6991220598759
#                 total:
#                     - 450.28331913764214
#             moderate:
#                 average:
#                     - 18.048244514086388
#                 total:
#                     - 866.3157366761467
#             low:
#                 average:
#                     - 21.718472080680986
#                 total:
#                     - 369.2140253715768
#     waitingInQueue:
#         duration:
#             critical:
#                 average:
#                     - 60.17636392732292
#                 total:
#                     - 361.0581835639375
#             urgent:
#                 average:
#                     - 79.93748505525194
#                 total:
#                     - 1518.812216049787
#             moderate:
#                 average:
#                     - 584.8814115372605
#                 total:
#                     - 28074.307753788507
#             low:
#                 average:
#                     - 1314.3776185351908
#                 total:
#                     - 22344.41951509824
#     assesment:
#         criticalEnterHospitalRatio:
#             - 1.0
#         urgentEnterHospitalRatio:
#             - 1.0
#         moderateEnterHospitalRatio:
#             - 0.4583333333333333
#         lowEnterHospitalRatio:
#             - 0.0588235294117647
# totalFinancials:
#     - 36900.0
# averageRevenuePerPatient:
#     - 369.0
# hospitalEntryRate:
#     - 0.48
# totalExpenses:
#     - 7279.860878376324
# totalProfit:
#     - 29620.139121623677
# averageProfitPerPatient:
#     - 296.20139121623674
