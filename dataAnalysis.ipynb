# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("results.csv")

# %%
df
# Out:
#    general_totalTime  general_totalPatients  proportion_CriticalPatients  \
# 0       20158.541622                   9442                     0.057827
# 1       20158.827125                   9208                     0.060165
# 2       20158.021606                   9512                     0.056770
#
#    proportion_UrgentPatients  proportion_ModeratePatients  \
# 0                   0.164054                     0.453612
# 1                   0.165834                     0.463184
# 2                   0.166106                     0.462153
#
#    proportion_LowPatients  proportion_NonUrgentPatients  \
# 0                0.000000                      0.113853
# 1                0.000326                      0.106321
# 2                0.000000                      0.110282
#
#    proportion_totalPatientsDeclinedAccess  arrival_waitingTime_average  \
# 0                                       0                     1.982793
# 1                                       0                     2.033647
# 2                                       0                     1.968543
#
#    arrival_waitingTime_total  ...  doctor_assesment_urgentEnterHospitalRatio  \
# 0               18721.532757  ...                                   0.881306
# 1               18725.819171  ...                                   0.881039
# 2               18724.776292  ...                                   0.888038
#
#    doctor_assesment_moderateEnterHospitalRatio  \
# 0                                     0.396899
# 1                                     0.404423
# 2                                     0.407594
#
#    doctor_assesment_lowEnterHospitalRatio  financials_entryRate  \
# 0                                     0.0              0.446092
# 1                                     0.0              0.455365
# 2                                     0.0              0.449432
#
#    financials_revenue_total  financials_revenue_perPatientAverage  \
# 0                   3118900                            330.321966
# 1                   3109700                            337.717202
# 2                   3167350                            332.984651
#
#    financials_expenses_total  financials_expenses_perPatientAverage  \
# 0                   153216.0                              16.227071
# 1                   153216.0                              16.639444
# 2                   153216.0                              16.107653
#
#    financials_profit_total  financials_profit_perPatientAverage
# 0                2965684.0                           314.094895
# 1                2956484.0                           321.077758
# 2                3014134.0                           316.876997
#
# [3 rows x 66 columns]

# %%
df["general_totalPatients"]
# Out:
# 0    9442
# 1    9208
# 2    9512
# Name: general_totalPatients, dtype: int64

# %%
# Create a nested dictionary to group metrics by all underscore levels
grouped_metrics = {}

for col in df.columns:
    parts = col.split('_')
    
    # Navigate/create nested dictionary structure
    current_dict = grouped_metrics
    for level in parts[:-1]:  # All parts except the last one are levels
        if level not in current_dict:
            current_dict[level] = {}
        current_dict = current_dict[level]
    
    # Store the final value
    final_level = parts[-1]
    if isinstance(current_dict, dict):
        current_dict[final_level] = df[col].mean()

# Helper function to print nested dictionary with proper indentation
def print_nested_dict(d, indent=0):
    for key, value in d.items():
        print("    " * indent + f"{key}:")
        if isinstance(value, dict):
            print_nested_dict(value, indent + 1)
        else:
            print("    " * (indent + 1) + f"- {value}")

# Print grouped metrics in desired format
print_nested_dict(grouped_metrics)
# Out:
# general:
#     totalTime:
#         - 20158.4634509876
#     totalPatients:
#         - 9387.333333333334
# proportion:
#     CriticalPatients:
#         - 0.0582540669212142
#     UrgentPatients:
#         - 0.1653314181818675
#     ModeratePatients:
#         - 0.45964959348396023
#     LowPatients:
#         - 0.0001086012163336
#     NonUrgentPatients:
#         - 0.11015177913539358
#     totalPatientsDeclinedAccess:
#         - 0.0
# arrival:
#     waitingTime:
#         average:
#             - 1.9949941248789544
#         total:
#             - 18724.042739886485
# reception:
#     serviceTime:
#         duration:
#             average:
#                 - 3.0029668666241522
#             total:
#                 - 28189.514759520982
#     waitingInQueue:
#         duration:
#             average:
#                 - 3.859392689156657
#             total:
#                 - 36242.91513288495
# nurse:
#     proportion:
#         moderatePatients:
#             - 0.628910123663397
#         lowPatients:
#             - 0.2495033417520359
#     serviceTime:
#         duration:
#             moderate:
#                 average:
#                     - 3.376066696809744
#                 total:
#                     - 17100.091975923857
#             low:
#                 average:
#                     - 4.256199473331818
#                 total:
#                     - 8560.127609926103
#     waitingInQueue:
#         duration:
#             moderate:
#                 average:
#                     - 0.10985068163092282
#                 total:
#                     - 556.4659616420804
#             low:
#                 average:
#                     - 0.15403331173285947
#                 total:
#                     - 310.8291816994743
#     revaluations:
#         moderate:
#             toCritical:
#                 - 0.017426944571401832
#             toUrgent:
#                 - 0.0230927551872806
#             toModerate:
#                 - 0.8580034063993333
#             toLow:
#                 - 0.028139780105438664
#             toNon-urgent:
#                 - 0.004745214166550201
#         low:
#             toCritical:
#                 - 0.00016608536787906668
#             toUrgent:
#                 - 0.006929697601038599
#             toModerate:
#                 - 0.03882091711381926
#             toLow:
#                 - 0.8395337795471928
#             toNon-urgent:
#                 - 0.04754989435107403
# doctor:
#     proportion:
#         totalPatients:
#             - 8974.0
#         criticalPatients:
#             - 0.06534759642668296
#         urgentPatients:
#             - 0.1871351465219985
#         moderatePatients:
#             - 0.5290387643901362
#         lowPatients:
#             - 0.21847849266118222
#     serviceTime:
#         duration:
#             critical:
#                 average:
#                     - 4.637858654704492
#                 total:
#                     - 2719.396044146372
#             urgent:
#                 average:
#                     - 6.444632727612711
#                 total:
#                     - 10822.32172824094
#             moderate:
#                 average:
#                     - 8.97022701537715
#                 total:
#                     - 42582.750881995315
#             low:
#                 average:
#                     - 0.008396468838312934
#                 total:
#                     - 15.852533166734853
#     waitingInQueue:
#         duration:
#             critical:
#                 average:
#                     - 2.9714144717633064
#                 total:
#                     - 1742.129585989228
#             urgent:
#                 average:
#                     - 4.1225179798169975
#                 total:
#                     - 6922.997604267014
#             moderate:
#                 average:
#                     - 344.10412559527686
#                 total:
#                     - 1635341.473386076
#             low:
#                 average:
#                     - 4.10597392803863
#                 total:
#                     - 7752.078776136933
#     assesment:
#         criticalEnterHospitalRatio:
#             - 0.932353079214618
#         urgentEnterHospitalRatio:
#             - 0.8834606663124828
#         moderateEnterHospitalRatio:
#             - 0.40297171949479643
#         lowEnterHospitalRatio:
#             - 0.0
# financials:
#     entryRate:
#         - 0.45029637526996513
#     revenue:
#         total:
#             - 3131983.3333333335
#         perPatientAverage:
#             - 333.6746063617009
#     expenses:
#         total:
#             - 153216.0
#         perPatientAverage:
#             - 16.324722662667927
#     profit:
#         total:
#             - 2978767.3333333335
#         perPatientAverage:
#             - 317.349883699033
