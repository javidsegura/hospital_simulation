# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("results.csv")

# %%
df
# Out:
#    general_totalTime  general_totalPatients  proportion_CriticalPatients  \
# 0         199.973765                    100                         0.05
# 1         183.342755                    100                         0.05
# 2         235.276845                    100                         0.05
#
#    proportion_UrgentPatients  proportion_ModeratePatients  \
# 0                       0.16                         0.53
# 1                       0.23                         0.50
# 2                       0.25                         0.47
#
#    proportion_LowPatients  proportion_NonUrgentPatients  \
# 0                    0.16                          0.02
# 1                    0.13                          0.02
# 2                    0.14                          0.05
#
#    proportion_totalPatientsDeclinedAccess  arrival_waitingTime_average  \
# 0                                       8                     1.999738
# 1                                       7                     1.833428
# 2                                       4                     2.352768
#
#    arrival_waitingTime_total  ...  doctor_assesment_urgentEnterHospitalRatio  \
# 0                 199.973765  ...                                   0.937500
# 1                 183.342755  ...                                   0.956522
# 2                 235.276845  ...                                   0.960000
#
#    doctor_assesment_moderateEnterHospitalRatio  \
# 0                                     0.509434
# 1                                     0.340000
# 2                                     0.382979
#
#    doctor_assesment_lowEnterHospitalRatio  financials_entryRate  \
# 0                                0.062500                  0.48
# 1                                0.153846                  0.46
# 2                                0.071429                  0.48
#
#    financials_revenue_total  financials_revenue_perPatientAverage  \
# 0                     35650                                 356.5
# 1                     36000                                 360.0
# 2                     37150                                 371.5
#
#    financials_expenses_total  financials_expenses_perPatientAverage  \
# 0                7952.989167                              79.529892
# 1                7980.216052                              79.802161
# 2                6854.701770                              68.547018
#
#    financials_profit_total  financials_profit_perPatientAverage
# 0             27697.010833                           276.970108
# 1             28019.783948                           280.197839
# 2             30295.298230                           302.952982
#
# [3 rows x 66 columns]

# %%
df["general_totalPatients"]
# Out:
# 0    100
# 1    100
# 2    100
# Name: general_totalPatients, dtype: int64

# %%
# Create a nested dictionary to group metrics by all underscore levels
grouped_metrics = {}

for col in df.columns:
    parts = col.split('_')
    
    # Navigate/create nested dictionary structure
    current_dict = grouped_metrics
    for level in parts[:-1]:  # All parts except the last one are levels
        if level not in current_dict:
            current_dict[level] = {}
        current_dict = current_dict[level]
    
    # Store the final value
    final_level = parts[-1]
    if isinstance(current_dict, dict):
        current_dict[final_level] = df[col].mean()

# Helper function to print nested dictionary with proper indentation
def print_nested_dict(d, indent=0):
    for key, value in d.items():
        print("    " * indent + f"{key}:")
        if isinstance(value, dict):
            print_nested_dict(value, indent + 1)
        else:
            print("    " * (indent + 1) + f"- {value}")

# Print grouped metrics in desired format
print_nested_dict(grouped_metrics)
# Out:
# general:
#     totalTime:
#         - 206.19778833441163
#     totalPatients:
#         - 100.0
# proportion:
#     CriticalPatients:
#         - 0.05000000000000001
#     UrgentPatients:
#         - 0.21333333333333335
#     ModeratePatients:
#         - 0.5
#     LowPatients:
#         - 0.14333333333333334
#     NonUrgentPatients:
#         - 0.03
#     totalPatientsDeclinedAccess:
#         - 6.333333333333333
# arrival:
#     waitingTime:
#         average:
#             - 2.0619778833441162
#         total:
#             - 206.19778833441163
# reception:
#     serviceTime:
#         duration:
#             average:
#                 - 10.543028475900208
#             total:
#                 - 1054.3028475900207
#     waitingInQueue:
#         duration:
#             average:
#                 - 151.17701638013668
#             total:
#                 - 15117.701638013668
# nurse:
#     proportion:
#         moderatePatients:
#             - 0.765742461012389
#         lowPatients:
#             - 0.2005379100131662
#     serviceTime:
#         duration:
#             moderate:
#                 average:
#                     - 3.633930611378474
#                 total:
#                     - 193.77173327643996
#             low:
#                 average:
#                     - 4.3354943391304985
#                 total:
#                     - 60.32582867066218
#     waitingInQueue:
#         duration:
#             moderate:
#                 average:
#                     - 0.007833164693153366
#                 total:
#                     - 0.40929887759358036
#             low:
#                 average:
#                     - 0.03717018872702007
#                 total:
#                     - 0.5947230196323213
#     revaluations:
#         moderate:
#             toCritical:
#                 - 0.006172839506172833
#             toUrgent:
#                 - 0.0371756783521489
#             toModerate:
#                 - 0.9186373539314715
#             toLow:
#                 - 0.0314781804977883
#             toNon-urgent:
#                 - 0.006535947712418301
#         low:
#             toCritical:
#                 - 0.0
#             toUrgent:
#                 - 0.0
#             toModerate:
#                 - 0.0721153846153846
#             toLow:
#                 - 0.9022435897435899
#             toNon-urgent:
#                 - 0.025641025641025633
# doctor:
#     proportion:
#         totalPatients:
#             - 90.66666666666667
#         criticalPatients:
#             - 0.0551485551485551
#         urgentPatients:
#             - 0.23508343508343502
#         moderatePatients:
#             - 0.5516076516076516
#         lowPatients:
#             - 0.1581603581603581
#     serviceTime:
#         duration:
#             critical:
#                 average:
#                     - 13.076677532748448
#                 total:
#                     - 65.38338766374225
#             urgent:
#                 average:
#                     - 23.54753825967541
#                 total:
#                     - 488.85513537998287
#             moderate:
#                 average:
#                     - 21.64183340818069
#                 total:
#                     - 1084.790801020539
#             low:
#                 average:
#                     - 17.189840769096246
#                 total:
#                     - 245.557726066806
#     waitingInQueue:
#         duration:
#             critical:
#                 average:
#                     - 18.777032227947767
#                 total:
#                     - 93.88516113973884
#             urgent:
#                 average:
#                     - 81.13595093721132
#                 total:
#                     - 1776.3092227123234
#             moderate:
#                 average:
#                     - 767.529223756066
#                 total:
#                     - 38268.20149686805
#             low:
#                 average:
#                     - 1392.8905825833579
#                 total:
#                     - 19854.509460640355
#     assesment:
#         criticalEnterHospitalRatio:
#             - 1.0
#         urgentEnterHospitalRatio:
#             - 0.9513405797101449
#         moderateEnterHospitalRatio:
#             - 0.41080422855613535
#         lowEnterHospitalRatio:
#             - 0.0959249084249084
# financials:
#     entryRate:
#         - 0.47333333333333333
#     revenue:
#         total:
#             - 36266.666666666664
#         perPatientAverage:
#             - 362.6666666666667
#     expenses:
#         total:
#             - 7595.968996342253
#         perPatientAverage:
#             - 75.95968996342253
#     profit:
#         total:
#             - 28670.697670324415
#         perPatientAverage:
#             - 286.70697670324415
