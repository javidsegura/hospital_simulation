# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("results.csv")

# %%
df
# Out:
#    general_totalTime  general_totalPatients  proportion_CriticalPatients  \
# 0          97.317478                     20                         0.05
#
#    proportion_UrgentPatients  proportion_ModeratePatients  \
# 0                       0.15                         0.05
#
#    proportion_LowPatients  proportion_NonUrgentPatients  \
# 0                     0.0                          0.15
#
#    proportion_totalPatientsDeclinedAccess  arrival_waitingTime_average  \
# 0                                       0                     4.865874
#
#    arrival_waitingTime_total  ...  \
# 0                  97.317478  ...
#
#    doctor_waitingInQueue_duration_urgent_average  \
# 0                                      13.330221
#
#    doctor_waitingInQueue_duration_urgent_total  \
# 0                                    53.320885
#
#    doctor_waitingInQueue_duration_moderate_average  \
# 0                                           6.8765
#
#    doctor_waitingInQueue_duration_moderate_total  \
# 0                                      27.505998
#
#    doctor_waitingInQueue_duration_low_average  \
# 0                                         0.0
#
#    doctor_waitingInQueue_duration_low_total  \
# 0                                         0
#
#    doctor_assesment_criticalEnterHospitalRatio  \
# 0                                          1.0
#
#    doctor_assesment_urgentEnterHospitalRatio  \
# 0                                       0.75
#
#    doctor_assesment_moderateEnterHospitalRatio  \
# 0                                          0.0
#
#    doctor_assesment_lowEnterHospitalRatio
# 0                                     0.0
#
# [1 rows x 59 columns]

# %%
df["general_totalTime"]
# Out:
# 0    97.317478
# Name: general_totalTime, dtype: float64

# %%
# Create a nested dictionary to group metrics by all underscore levels
grouped_metrics = {}

for col in df.columns:
    parts = col.split('_')
    
    # Navigate/create nested dictionary structure
    current_dict = grouped_metrics
    for level in parts[:-1]:  # All parts except the last one are levels
        if level not in current_dict:
            current_dict[level] = {}
        current_dict = current_dict[level]
    
    # Store the final value
    final_level = parts[-1]
    if isinstance(current_dict, dict):
        current_dict[final_level] = df[col].mean()

# Helper function to print nested dictionary with proper indentation
def print_nested_dict(d, indent=0):
    for key, value in d.items():
        print("    " * indent + f"{key}:")
        if isinstance(value, dict):
            print_nested_dict(value, indent + 1)
        else:
            print("    " * (indent + 1) + f"- {value}")

# Print grouped metrics in desired format
print_nested_dict(grouped_metrics)
# Out:
# general:
#     totalTime:
#         - 97.31747826685368
#     totalPatients:
#         - 20.0
# proportion:
#     CriticalPatients:
#         - 0.05
#     UrgentPatients:
#         - 0.15
#     ModeratePatients:
#         - 0.05
#     LowPatients:
#         - 0.0
#     NonUrgentPatients:
#         - 0.15
#     totalPatientsDeclinedAccess:
#         - 0.0
# arrival:
#     waitingTime:
#         average:
#             - 4.865873913342684
#         total:
#             - 97.31747826685368
# reception:
#     serviceTime:
#         duration:
#             average:
#                 - 6.356411888807282
#             total:
#                 - 127.12823777614564
#     waitingInQueue:
#         duration:
#             average:
#                 - 2.4161487167614717
#             total:
#                 - 48.32297433522943
# nurse:
#     proportion:
#         moderatePatients:
#             - 0.8
#         lowPatients:
#             - 0.2
#     serviceTime:
#         duration:
#             moderate:
#                 average:
#                     - 6.325978217196404
#                 total:
#                     - 25.303912868785616
#             low:
#                 average:
#                     - 6.186699856595862
#                 total:
#                     - 6.186699856595862
#     waitingInQueue:
#         duration:
#             moderate:
#                 average:
#                     - 0.0
#                 total:
#                     - 0.0
#             low:
#                 average:
#                     - 0.0
#                 total:
#                     - 0.0
#     revaluations:
#         moderate:
#             toCritical:
#                 - 0.0
#             toUrgent:
#                 - 0.0
#             toModerate:
#                 - 1.0
#             toLow:
#                 - 0.0
#             toNon-urgent:
#                 - 0.0
#         low:
#             toCritical:
#                 - 0.0
#             toUrgent:
#                 - 0.0
#             toModerate:
#                 - 0.0
#             toLow:
#                 - 1.0
#             toNon-urgent:
#                 - 0.0
# doctor:
#     proportion:
#         totalPatients:
#             - 10.0
#         criticalPatients:
#             - 0.1
#         urgentPatients:
#             - 0.4
#         moderatePatients:
#             - 0.4
#         lowPatients:
#             - 0.1
#     serviceTime:
#         duration:
#             critical:
#                 average:
#                     - 9.72526186614098
#                 total:
#                     - 9.72526186614098
#             urgent:
#                 average:
#                     - 6.55446454106711
#                 total:
#                     - 26.21785816426844
#             moderate:
#                 average:
#                     - 7.030372028004239
#                 total:
#                     - 28.121488112016955
#             low:
#                 average:
#                     - 0.0
#                 total:
#                     - 0.0
#     waitingInQueue:
#         duration:
#             critical:
#                 average:
#                     - 0.0
#                 total:
#                     - 0.0
#             urgent:
#                 average:
#                     - 13.330221172370264
#                 total:
#                     - 53.32088468948106
#             moderate:
#                 average:
#                     - 6.876499592174813
#                 total:
#                     - 27.505998368699252
#             low:
#                 average:
#                     - 0.0
#                 total:
#                     - 0.0
#     assesment:
#         criticalEnterHospitalRatio:
#             - 1.0
#         urgentEnterHospitalRatio:
#             - 0.75
#         moderateEnterHospitalRatio:
#             - 0.0
#         lowEnterHospitalRatio:
#             - 0.0
